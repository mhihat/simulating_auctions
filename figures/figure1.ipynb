# %% [markdown]
# # Generating Figure 1

# %%
# %load_ext autoreload
# %autoreload 2
from figure1_functions import *

# %% [markdown]
# #### Backward shooting ($n=5, k=5, \alpha=1$)

# %%
n_5=5; k_5=4; strength_5=1; strength_5_in=1; strength_5_out=1
out_5 = iterate_mGU([strength_5_in*k_5]+[strength_5_out]*(n_5-k_5),eps=10**-7)

# %%
display_bid_functions(1,n_5,k_5,strength_5,strength_5_in,strength_5_out,out_5)

# %% [markdown]
# #### Backward shooting ($n=10, k=8, \alpha=1/20$)

# %%
n_10=10; k_10=8; strength_10=1/20; strength_10_in=1/20; strength_10_out=1/20
out_10 = iterate_mGU([strength_10_in*k_10]+[strength_10_out]*(n_10-k_10),eps=10**-7)

# %%
display_bid_functions(2,n_10,k_10,strength_10,strength_10_in,strength_10_out,out_10)
